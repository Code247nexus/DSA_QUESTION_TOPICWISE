# %% [markdown]
# ##169. Majority Element
# Given an array nums of size n, return the majority element.
#
# The majority element is the element that appears more than ⌊n / 2⌋ times. You may assume that the majority element always exists in the array

# %%
# brute force approach
# function code
# timecomplexity->O(n^2)
# space complexity->O(1)
def majority_element(array):
  n = len(array)
  for i in range(0,n):
    count = 0
    for j in range(0,n):
      if array[i] == array[j]:
        count += 1
    if count > n/2:
      return array[i]
  return -1

#driver code
arr =[3,2,3]
result = majority_element(arr)
print("THE OUTPUT IS: ",result)
# Out:
# THE OUTPUT IS:  3

# %%
#sort of optimed approach
#function definition
#time complexity ->O(n)
#space complexity ->O(n)

def majority_element(array):
  hash_map = {}
  for nums in array:
    if nums not in hash_map:
      hash_map[nums] = 1
    else:
      hash_map[nums] += 1

  count = 0
  majority = None
  for key,value in hash_map.items():
    if value>count:
      count = value
      majority = key

  return majority
#driver code
arr =[3,2,3]
result = majority_element(arr)
print("THE OUTPUT IS: ",result)
# Out:
# THE OUTPUT IS:  3
